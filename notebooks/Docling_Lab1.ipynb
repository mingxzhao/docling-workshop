# %% [markdown]
# # Transform Your Documents into AI-Ready Data with Docling

# %% [markdown]
# ## Lab 1: Document Conversion
#
# Welcome to the first lab in our comprehensive Docling workshop series! This three-part journey will take you from document processing basics to building cutting-edge, transparent AI systems.

# %% [markdown]
# ## Overview: What You'll Build
#
# In this first lab, you'll learn how to transform complex documents into AI-ready structured data. But this isn't just about extraction - it's about intelligent conversion that preserves everything important for downstream AI applications.
#
# ### By the End of This Lab
#
# You'll have mastered:
# - **Document Loading**: Ingesting PDFs, Word docs, PowerPoints, and more
# - **Structure Extraction**: Preserving hierarchy and relationships
# - **Table Excellence**: Converting complex tables into usable formats
# - **Image Handling**: Extracting and preparing images for AI processing
# - **Metadata Preservation**: Maintaining information needed for visual grounding

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction
#
# **[Docling](https://docling-project.github.io/docling/)** is an open-source toolkit for document processing, parsing, and conversion designed for generative AI applications.
#
# ### Key Features
# - **Multi-format support**: PDF, DOCX, XLSX, HTML, images, and more
# - **Advanced PDF understanding**: Page layout, reading order, table structure, code blocks, formulas
# - **Unified DoclingDocument representation**: Consistent data structure across all formats
# - **Flexible export options**: Markdown, HTML, JSON, DocTags
# - **Local execution**: Process sensitive data without external services
# - **Framework integration**: LangChain, LlamaIndex, and other AI frameworks

# %% [markdown]
# ## Why we use Docling for Document Conversion
#
# Data is the foundation for all AI systems. In order to leverage as much data as possible, we need to be able to ingest data of various formats with accuracy. Howver, LLM's typically requre data in a specific format, thus the need for conversion.
#
# **Without proper conversion**:
# - Information gets lost or jumbled
# - Tables become unreadable text
# - Images disappear entirely
# - Document structure is destroyed
#
# **With Docling's advanced conversion**:
# - Every piece of information is preserved
# - Tables maintain their structure
# - Images are extracted and processable
# - Layout and relationships are understood

# %% [markdown]
# ## Installation and Setup

# %% [markdown]
# ### Setting up the environment
#
# Ensure you are running Python 3.10, 3.11 or 3.12 in a freshly created virtual environment.

# %%
import sys
assert sys.version_info >= (3, 10) and sys.version_info < (3, 13), "Use Python 3.10, 3.11, or 3.12 to run this notebook."

# %% [markdown]
# ### Basic Installation

# %%
! pip install docling[vlm] mlx-vlm matplotlib pillow pandas python-dotenv
# Out:
# Requirement already satisfied: mlx-vlm in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (0.1.26)
# Requirement already satisfied: matplotlib in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: pillow in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (11.2.1)
# Requirement already satisfied: pandas in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: python-dotenv in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: docling[vlm] in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (2.34.0)
# Requirement already satisfied: accelerate<2.0.0,>=1.2.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.7.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (4.13.4)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2025.4.26)
# Requirement already satisfied: click<8.2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (8.1.8)
# Requirement already satisfied: docling-core<3.0.0,>=2.31.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (2.31.2)
# Requirement already satisfied: docling-ibm-models<4.0.0,>=3.4.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (3.4.3)
# Requirement already satisfied: docling-parse<5.0.0,>=4.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (4.0.1)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (0.31.1)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (5.4.0)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2.1.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (3.1.5)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2.11.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2.9.1)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2.10)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (4.30.1)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (1.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (4.67.1)
# Requirement already satisfied: transformers<5.0.0,>=4.46.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (4.51.3)
# Requirement already satisfied: typer<0.16.0,>=0.12.5 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling[vlm]) (0.15.3)
# Requirement already satisfied: mlx>=0.25.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (0.25.2)
# Requirement already satisfied: datasets>=2.19.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (2.21.0)
# Requirement already satisfied: numpy>=1.23.4 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (2.2.5)
# Requirement already satisfied: gradio>=5.19.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (5.31.0)
# Requirement already satisfied: opencv-python==4.10.0.84 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (4.10.0.84)
# Requirement already satisfied: mlx-lm>=0.23.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (0.24.1)
# Requirement already satisfied: fastapi>=0.95.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-vlm) (0.115.12)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: psutil in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.2.1->docling[vlm]) (7.0.0)
# Requirement already satisfied: pyyaml in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.2.1->docling[vlm]) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.2.1->docling[vlm]) (2.7.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.2.1->docling[vlm]) (0.5.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling[vlm]) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling[vlm]) (4.13.2)
# Requirement already satisfied: filelock in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (0.3.8)
# Requirement already satisfied: xxhash in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (3.5.0)
# Requirement already satisfied: multiprocess in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.19.1->mlx-vlm) (2024.6.1)
# Requirement already satisfied: aiohttp in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from datasets>=2.19.1->mlx-vlm) (3.11.18)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (4.23.0)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (3.78.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (0.9.0)
# Requirement already satisfied: semchunk<3.0.0,>=2.2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (2.2.2)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling[vlm]) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling[vlm]) (4.11.0.86)
# Requirement already satisfied: torchvision<1,>=0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling[vlm]) (0.22.0)
# Requirement already satisfied: scikit-image in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling[vlm]) (0.24.0)
# Requirement already satisfied: python-bidi in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling[vlm]) (0.6.6)
# Requirement already satisfied: Shapely in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling[vlm]) (2.0.7)
# Requirement already satisfied: pyclipper in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling[vlm]) (1.3.0.post6)
# Requirement already satisfied: ninja in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from easyocr<2.0,>=1.7->docling[vlm]) (1.11.1.4)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from fastapi>=0.95.1->mlx-vlm) (0.46.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (4.9.0)
# Requirement already satisfied: ffmpy in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (3.10.18)
# Requirement already satisfied: pydub in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.11.12)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio>=5.19.0->mlx-vlm) (0.34.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from gradio-client==1.10.1->gradio>=5.19.0->mlx-vlm) (15.0.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from huggingface_hub<1,>=0.23->docling[vlm]) (1.1.1)
# Requirement already satisfied: protobuf in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from mlx-lm>=0.23.0->mlx-vlm) (6.30.2)
# Requirement already satisfied: et-xmlfile in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from openpyxl<4.0.0,>=3.1.5->docling[vlm]) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->docling[vlm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->docling[vlm]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->docling[vlm]) (0.4.0)
# Requirement already satisfied: six>=1.5 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from python-pptx<2.0.0,>=1.0.2->docling[vlm]) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling[vlm]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling[vlm]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.2->docling[vlm]) (2.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.46.0->docling[vlm]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.46.0->docling[vlm]) (0.21.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from typer<0.16.0,>=0.12.5->docling[vlm]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from typer<0.16.0,>=0.12.5->docling[vlm]) (14.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.19.0->mlx-vlm) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.19.1->mlx-vlm) (1.20.0)
# Requirement already satisfied: httpcore==1.* in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.19.0->mlx-vlm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.19.0->mlx-vlm) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.31.2->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (0.24.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<0.16.0,>=0.12.5->docling[vlm]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<0.16.0,>=0.12.5->docling[vlm]) (2.19.1)
# Requirement already satisfied: mpire[dill] in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.31.2->docling[vlm]) (2.10.2)
# Requirement already satisfied: setuptools in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate<2.0.0,>=1.2.1->docling[vlm]) (80.4.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate<2.0.0,>=1.2.1->docling[vlm]) (1.14.0)
# Requirement already satisfied: networkx in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate<2.0.0,>=1.2.1->docling[vlm]) (3.2.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from transformers[sentencepiece]>=4.39.3->mlx-lm>=0.23.0->mlx-vlm) (0.2.0)
# Requirement already satisfied: imageio>=2.33 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling[vlm]) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling[vlm]) (2024.8.30)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling[vlm]) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.16.0,>=0.12.5->docling[vlm]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate<2.0.0,>=1.2.1->docling[vlm]) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Import Essential Components

# %%
from pathlib import Path

# Core Docling imports
from docling.document_converter import DocumentConverter
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import PdfFormatOption

# For advanced features
from docling_core.types.doc import ImageRefMode, PictureItem, TableItem, TextItem, DoclingDocument

# For data processing and visualization
import matplotlib.pyplot as plt

# Create output directory
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

# %% [markdown]
# ## Basic Document Conversion
#
# ### Minimal Example
#
# The simplest way to convert a document:

# %%
# example document: Docling Technical Report
docling_paper = "https://arxiv.org/pdf/2501.17887"

# %%
# Simple conversion

# Create a converter instance
converter = DocumentConverter()

# Convert a document
result = converter.convert(docling_paper)
doc = result.document
# Out:
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/pva/work/github.com/DS4SD/docling/docling/pipeline/standard_pdf_pipeline.py:262: RuntimeWarning: Mean of empty slice
#   np.nanmean(
# /Users/pva/work/github.com/DS4SD/docling/docling/pipeline/standard_pdf_pipeline.py:267: RuntimeWarning: Mean of empty slice
#   np.nanmean(

# %%
# Export to Markdown
md_out = doc.export_to_markdown()

# printing an excerpt
print(f"{md_out[:2000]}...")
# Out:
# ## Docling: An Efficient Open-Source Toolkit for AI-driven Document Conversion
#
# Nikolaos Livathinos * , Christoph Auer * , Maksym Lysak, Ahmed Nassar, Michele Dolfi, Panagiotis Vagenas, Cesar Berrospi, Matteo Omenetti, Kasper Dinkla, Yusik Kim, Shubham Gupta, Rafael Teixeira de Lima, Valery Weber, Lucas Morin, Ingmar Meijer, Viktor Kuropiatnyk, Peter W. J. Staar
#
# IBM Research, R¨ uschlikon, Switzerland
#
# Please send correspondence to: deepsearch-core@zurich.ibm.com
#
# ## Abstract
#
# We introduce Docling , an easy-to-use, self-contained, MITlicensed, open-source toolkit for document conversion, that can parse several types of popular document formats into a unified, richly structured representation. It is powered by state-of-the-art specialized AI models for layout analysis (DocLayNet) and table structure recognition (TableFormer), and runs efficiently on commodity hardware in a small resource budget. Docling is released as a Python package and can be used as a Python API or as a CLI tool. Docling's modular architecture and efficient document representation make it easy to implement extensions, new features, models, and customizations. Docling has been already integrated in other popular open-source frameworks (e.g., LangChain, LlamaIndex, spaCy), making it a natural fit for the processing of documents and the development of high-end applications. The open-source community has fully engaged in using, promoting, and developing for Docling, which gathered 10k stars on GitHub in less than a month and was reported as the No. 1 trending repository in GitHub worldwide in November 2024.
#
# With Docling , we recently open-sourced a very capable and efficient document conversion tool which builds on the powerful, specialized AI models and datasets for layout analysis and table structure recognition that we developed and presented in the recent past (Livathinos et al. 2021; Pfitzmann et al. 2022; Lysak et al. 2023). Docling is designed as a simple, self-contained Python library with ...

# %% [markdown]
# ### Document Structure Exploration
#
# One of Docling's superpowers is understanding document structure. This becomes critical in Lab 2 (chunking) and Lab 3 (visual grounding).
#
# Let's explore what Docling discovers:

# %%
# Document metadata - important for tracking
print(f"Document title: {doc.name}")
print(f"Number of pages: {len(doc.pages)}")
print(f"Number of tables: {len(doc.tables)}")
print(f"Number of pictures: {len(doc.pictures)}")

# Explore the document structure
print("\nDocument structure:")
for i, (item, level) in enumerate(doc.iterate_items()):
    if i < 10:  # Show first 10 items
        item_type = type(item).__name__
        text_preview = item.text[:200] if hasattr(item, 'text') else 'N/A'
        print(f"{'  ' * level}{item_type}: {text_preview}")
# Out:
# Document title: 2501.17887v1
# Number of pages: 8
# Number of tables: 1
# Number of pictures: 6
#
# Document structure:
#   SectionHeaderItem: Docling: An Efficient Open-Source Toolkit for AI-driven Document Conversion
#   TextItem: Nikolaos Livathinos * , Christoph Auer * , Maksym Lysak, Ahmed Nassar, Michele Dolfi, Panagiotis Vagenas, Cesar Berrospi, Matteo Omenetti, Kasper Dinkla, Yusik Kim, Shubham Gupta, Rafael Teixeira de L
#     TextItem: IBM Research, R¨ uschlikon, Switzerland
#     TextItem: Please send correspondence to: deepsearch-core@zurich.ibm.com
#   SectionHeaderItem: Abstract
#   TextItem: We introduce Docling , an easy-to-use, self-contained, MITlicensed, open-source toolkit for document conversion, that can parse several types of popular document formats into a unified, richly structu
#   TextItem: With Docling , we recently open-sourced a very capable and efficient document conversion tool which builds on the powerful, specialized AI models and datasets for layout analysis and table structure r
#   TextItem: Repository -https://github.com/DS4SD/docling
#   SectionHeaderItem: 1 Introduction
#   TextItem: Converting documents back into a unified machineprocessable format has been a major challenge for decades due to their huge variability in formats, weak standardization and printing-optimized characte

# %% [markdown]
# ## Export Formats and Options
#
# Docling supports multiple export formats with various options:

# %%
# Export to different formats (various options available, but called with default ones)
markdown_text = doc.export_to_markdown()
html_text = doc.export_to_html()
json_dict = doc.export_to_dict()
doc_tags = doc.export_to_doctags()

# Save different formats (various options available, some shown)
doc.save_as_markdown(
    output_dir / "document.md",
    image_mode=ImageRefMode.PLACEHOLDER,
    image_placeholder="<!-- my image placeholder -->",
    # ...
)

# ...

# Export as JSON
doc.save_as_json(
    output_dir / "document.json",
)

# %% [markdown]
# ## Working with Tables
#
# Docling provides excellent table extraction capabilities, for this example, let's use a document with more tables, found [here](https://midwestfoodbank.org/images/AR_2020_WEB2.pdf)

# %% [markdown]
# ### Basic Table Export

# %%
# example document with tables
tables_example = "https://arxiv.org/pdf/2502.09927"

# %%
# Convert a document with tables
table_result = converter.convert(tables_example)
table_doc = table_result.document
# Out:
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
print(f"\nDocument contains {len(table_doc.tables)} tables")

# Export all tables
for table_idx, table in enumerate(table_doc.tables):
    # Convert to pandas DataFrame
    df = table.export_to_dataframe()

    print(f"\n## Table {table_idx}")
    print(f"Shape: {df.shape}")
    display(df.head())

    # Save as CSV
    df.to_csv(output_dir / f"table_{table_idx}.csv", index=False)

    # Save as HTML
    with open(output_dir / f"table_{table_idx}.html", "w") as fp:
        fp.write(table.export_to_html(doc=table_doc))
# Out:
# Document contains 15 tables
#
# ## Table 0
# Shape: (4, 4)
#                           Cauldron LLaVa-OneVision Cambrian-7m
# 0                 General  276.5 K         881.3 K       1.8 M
# 1     Language/Captioning  202.1 K             N/A         N/A
# 2  Math/Science/Reasoning  178.4 K         318.0 K     354.5 K
# 3        Image Comparison  188.9 K             N/A         N/A
# ## Table 1
# Shape: (4, 4)
#                           Cauldron LLaVa-OneVision Cambrian-7m
# 0                 General  812.7 K           2.0 M       7.9 M
# 1     Language/Captioning  203.3 K           1.2 M       1.8 M
# 2  Math/Science/Reasoning  765.1 K         464.8 K     802.0 K
# 3        Image Comparison  237.9 K             N/A         N/A
# ## Table 2
# Shape: (26, 16)
#                 Model                Size     Document.DocVQA  \
# 0  Small models 1B-4B  Small models 1B-4B  Small models 1B-4B
# 1             Molmo-E                  1B                0.66
# 2              MM1.5*                  1B                0.81
# 3            SmolVLM*                2.2B                0.80
# 4              MM1.5*                  3B                0.87
#
#      Document.ChartQA    Document.TextVQA       Document.AI2D  \
# 0  Small models 1B-4B  Small models 1B-4B  Small models 1B-4B
# 1                0.60                0.62                0.63
# 2                0.67                0.72                0.59
# 3                0.72                0.72                0.84
# 4                0.74                0.76                0.66
#
#      Document.InfoVQA   Document.OCRBench     Document.WebSRC  \
# 0  Small models 1B-4B  Small models 1B-4B  Small models 1B-4B
# 1                0.44                0.65                0.68
# 2                0.50                   -                   -
# 3                   -                0.65                   -
# 4                0.58                   -                   -
#
#   Document.LiveXiv VQA Other benchmarks.LiveXiv TQA Other benchmarks.MMMU  \
# 0   Small models 1B-4B           Small models 1B-4B    Small models 1B-4B
# 1                 0.47                         0.36                  0.32
# 2                    -                            -                  0.36
# 3                    -                            -                  0.38
# 4                    -                            -                  0.37
#
#   Other benchmarks.VQAv2 Other benchmarks.RealWorldQA  \
# 0     Small models 1B-4B           Small models 1B-4B
# 1                   0.57                         0.55
# 2                      -                         0.53
# 3                      -                            -
# 4                      -                         0.57
#
#   Other benchmarks.VizWiz VQA Other benchmarks.OK VQA
# 0          Small models 1B-4B      Small models 1B-4B
# 1                        0.49                    0.40
# 2                           -                       -
# 3                           -                       -
# 4                           -                       -
# ## Table 3
# Shape: (9, 6)
#                 Model                Size Table Extraction.PubTables  \
# 0  Small models 1B-4B  Small models 1B-4B         Small models 1B-4B
# 1             Molmo-E                  1B                       0.28
# 2             SmolVLM                2.2B                       0.32
# 3             Phi3.5v                  4B                       0.58
# 4      Granite Vision                  3B                       0.70
#
#   Table Extraction.FinTabNet Chart Extraction.MD Chart Extraction.HTML
# 0         Small models 1B-4B  Small models 1B-4B    Small models 1B-4B
# 1                       0.28                0.57                  0.54
# 2                       0.18                0.12                  0.02
# 3                       0.28                0.77                  0.40
# 4                       0.54                0.93                  0.95
# ## Table 4
# Shape: (4, 7)
#                   Model. VLGuard.Unsafe VLGuard.Safe-Unsafe RTVLM.Mislead  \
# 0          LLaVA-v1.5-7B            5.3                 7.4           8.6
# 1          Phi3.5-vision            8.7                 9.3           8.5
# 2                SmolVLM            4.8                 7.7           5.6
# 3  Granite Vision (Ours)            6.5                 8.6           7.7
#
#   RTVLM.Politics RTVLM.Racial RTVLM.Jailbreak
# 0            7.3          7.2             4.4
# 1            8.2          8.2             9.3
# 2            6.0          4.6             7.3
# 3            7.2          7.7             4.5
# ## Table 5
# Shape: (2, 3)
#                    MHalu VLGuard
# 0   Granite Vision  78.0    86.0
# 1  +Safety Vectors  80.7    96.2
# ## Table 6
# Shape: (14, 1)
#                                                    0
# 0  Tupini, Praneetha Vaddamanu, Chunyu Wang, Guan...
# 1  Marah Abdin, Jyoti Aneja, Hany Awadalla, Ahmed...
# 2  Pravesh Agrawal, Szymon Antoniak, Emma Bou Han...
# 3  Jean-Baptiste Alayrac, Jeff Donahue, Pauline L...
# 4  Anthropic. Claude 3.5 sonnet, 2024. URL https:...
# ## Table 7
# Shape: (17, 1)
#                                                    0
# 0  Wenliang Dai, Nayeon Lee, Boxin Wang, Zhuolin ...
# 1  Matt Deitke, Christopher Clark, Sangho Lee, Ro...
# 2  Matt Deitke, Christopher Clark, Sangho Lee, Ro...
# 3  Xiang Deng, Huan Sun, Alyssa Lees, You Wu, and...
# 4  Hao Feng, Qi Liu, Hao Liu, Jingqun Tang, Wenga...
# ## Table 8
# Shape: (20, 1)
#                                                    0
# 0  HuggingFace. Docmatix: A new approach to docum...
# 1  Kushal Kafle, Brian Price, Scott Cohen, and Ch...
# 2  Samira Ebrahimi Kahou, Vincent Michalski, Adam...
# 3  Raghav Kapoor, Yash Parag Butala, Melisa Russa...
# 4  Aniruddha Kembhavi, Mike Salvato, Eric Kolve, ...
# ## Table 9
# Shape: (18, 1)
#                                                    0
# 0  Chaohu Liu, Kun Yin, Haoyu Cao, Xinghua Jiang,...
# 1  Fangyu Liu, Julian Martin Eisenschlos, Frances...
# 2  Haotian Liu, Chunyuan Li, Yuheng Li, and Yong ...
# 3  Haotian Liu, Chunyuan Li, Qingyang Wu, and Yon...
# 4  Yuliang Liu, Zhang Li, Mingxin Huang, Biao Yan...
# ## Table 10
# Shape: (15, 1)
#                                                    0
# 0  Oshri Naparstek, Ophir Azulai, Inbar Shapira, ...
# 1  Ahmed Nassar, Nikolaos Livathinos, Maksym Lysa...
# 2  Jason Obeid and Enamul Hoque. Chart-to-text: G...
# 3  OpenAI. Gpt-4 technical report. ArXiv , abs/23...
# 4  OpenAI. Gpt-4v(ision) technical work and autho...
# ## Table 11
# Shape: (18, 1)
#                                                    0
# 0  Benny J Tang, Angie Boggust, and Arvind Satyan...
# 1  Gemini Team, Petko Georgiev, Ving Ian Lei, Rya...
# 2  Shengbang Tong, Ellis Brown, Penghao Wu, Sangh...
# 3  Michał Turski, Tomasz Stanisławek, Karol Kaczm...
# 4  Michał Turski, Tomasz Stanisławek, Karol Kaczm...
# ## Table 12
# Shape: (7, 1)
#                                                    0
# 0  Liang Zhang, Anwen Hu, Haiyang Xu, Ming Yan, Y...
# 1  Yanzhe Zhang, Ruiyi Zhang, Jiuxiang Gu, Yufan ...
# 2  Yilun Zhao, Yunxiang Li, Chenying Li, and Rui ...
# 3  Yilun Zhao, Chen Zhao, Linyong Nan, Zhenting Q...
# 4  Xinyi Zheng, Doug Burdick, Lucian Popa, Peter ...
# ## Table 13
# Shape: (46, 3)
#                                Datasets # Images # QA Pairs
# 0                           Document QA
# 1                             DocFM-VQA    2.4 M     19.9 M
# 2  Docmatix (Laurencon ¸ et al., 2024a)  565.0 K      3.9 M
# 3       synthdog-en (Kim et al., 2022a)  500.0 K    500.0 K
# 4     pixmo-docs (Deitke et al., 2024b)  255.4 K      2.3 M
# ## Table 14
# Shape: (31, 3)
#                                             Datasets # Images # QA Pairs
# 0                      Grounding / Text Localization
# 1  Multi-grained Text Localization (Hu et al., 20...    1.0 M      1.0 M
# 2                         DocFM Rule Based Grounding    190 K    534.4 K
# 3                    KVP10K (Naparstek et al., 2024)    8.0 K      8.0 K
# 4                                         Scene Text

# %% [markdown]
# ## Image and Figure Extraction
#
# Docling also provides image extraction capabilities

# %% [markdown]
# ### Extracting and Visualizing Page Images

# %%
# example document with images
images_example = "https://midwestfoodbank.org/images/AR_2020_WEB2.pdf"

# %%
# Configure pipeline to extract images
IMAGE_RESOLUTION_SCALE = 2.0  # 2x resolution (144 DPI)

pipeline_options = PdfPipelineOptions(
    images_scale=IMAGE_RESOLUTION_SCALE,
    generate_page_images=True,
    generate_picture_images=True,
)

converter_with_images = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# Convert with image extraction
img_result = converter_with_images.convert(docling_paper)
img_doc = img_result.document
# Out:
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/pva/work/github.com/DS4SD/docling/docling/pipeline/standard_pdf_pipeline.py:262: RuntimeWarning: Mean of empty slice
#   np.nanmean(
# /Users/pva/work/github.com/DS4SD/docling/docling/pipeline/standard_pdf_pipeline.py:267: RuntimeWarning: Mean of empty slice
#   np.nanmean(

# %%
# Create images subdirectory
images_dir = output_dir / "images"
images_dir.mkdir(exist_ok=True)

# Save page images
for page_no, page in img_doc.pages.items():
    page_image_filename = images_dir / f"page_{page_no}.png"
    with page_image_filename.open("wb") as fp:
        page.image.pil_image.save(fp, format="PNG")

print(f"Saved {len(img_doc.pages)} page images")
# Out:
# Saved 8 page images

# %% [markdown]
# ### Extract Figures and Tables as Images
#
# For custom processing, we can also extract figures and tables as images:

# %%
# Extract all figures and tables as separate images
table_counter = 0
picture_counter = 0

for element, level in img_doc.iterate_items():
    if isinstance(element, TableItem):
        table_counter += 1
        image_filename = images_dir / f"table_{table_counter}.png"
        with image_filename.open("wb") as fp:
            element.get_image(img_doc).save(fp, "PNG")

    elif isinstance(element, PictureItem):
        picture_counter += 1
        image_filename = images_dir / f"figure_{picture_counter}.png"
        with image_filename.open("wb") as fp:
            element.get_image(img_doc).save(fp, "PNG")

print(f"Extracted {table_counter} tables and {picture_counter} figures as images")
# Out:
# Extracted 1 tables and 6 figures as images

# %% [markdown]
# ### Inspecting Picture Content
#
# Docling will automatically generate captions and extract text content from extracted images. Let's take a look at what is extracted:

# %%
def inspect_pictures_with_images(doc: DoclingDocument, image_size=(6, 4)):
    """Display pictures inline with their text content"""
    for idx, picture in enumerate(doc.pictures):
        print(f"\n{'='*60}")
        print(f"Picture {idx}")
        print(f"{'='*60}")

        # Display the image
        try:
            img = picture.get_image(doc)
            if img:
                plt.figure(figsize=image_size)
                plt.imshow(img)
                plt.axis('off')
                plt.title(f"Picture {idx}")
                plt.show()
        except Exception as e:
            print(f"Could not display image: {e}")

        # Display metadata
        caption = picture.caption_text(doc)
        if caption:
            print(f"\nCaption: {caption}")

        if hasattr(picture, 'prov') and picture.prov:
            print(f"Location: Page {picture.prov[0].page_no}")

        # Display embedded text
        print("\nEmbedded text elements:")
        text_found = False
        for item, level in doc.iterate_items(root=picture, traverse_pictures=True):
            if isinstance(item, TextItem):
                print(f"{'  ' * (level + 1)}- {item.text}")
                text_found = True

        if not text_found:
            print("  (No text elements found)")

# Use the simple inline display
inspect_pictures_with_images(img_doc)
# Out:
# ============================================================
# Picture 0
# ============================================================
# Caption: Figure 1: Sketch of Docling's pipelines and usage model. Both PDF pipeline and simple pipeline build up a DoclingDocument representation, which can be further enriched. Downstream applications can utilize Docling's API to inspect, export, or chunk the document for various purposes.
# Location: Page 2
#
# Embedded text elements:
#     - Figure 1: Sketch of Docling's pipelines and usage model. Both PDF pipeline and simple pipeline build up a DoclingDocument representation, which can be further enriched. Downstream applications can utilize Docling's API to inspect, export, or chunk the document for various purposes.
#     - </>
#     - Simple Pipeline
#     - Parse Markup
#     - Format
#     - Build
#     - Enrich
#     - PDF Pipeline
#     - Assemble
#     - Document
#     - Layout
#     - Analysis
#     - Parse PDF
#     - pages
#     - Table
#     - Structure
#     - OCR
#     - Use
#     - Build
#     - Assemble
#     - Document
#     - Export JSON,
#     - Markdown,
#     - HTML,
#     - Figures,
#     - …
#     - {;}
#     - ##
#     - …
#     - Chunking
#     - for RAG
#     - Docling
#     - Document
#     - ascii
#     - docx
#     - pptx
#     - xlsx
#     - md
#     - html
#     - AsciiDoc
#     - pdf
#     - images
#
# ============================================================
# Picture 1
# ============================================================
# Caption: Figure 2: Dataset categories and sample counts for documents and pages.
# Location: Page 5
#
# Embedded text elements:
#     - Figure 2: Dataset categories and sample counts for documents and pages.
#     - Annual Reports
#     - 20
#     - CCPdf (misc)
#     - 39
#     - Law and Regulations
#     - 4
#     - Manuals
#     - 8
#     - Patents
#     - 5
#     - Science
#     - 9
#     - Spec sheets
#     - 4
#     - Documents per Category
#     - Annual Reports
#     - 1554
#     - CCPdf (misc)
#     - 1090
#     - Law and Regulations
#     - 68
#     - Manuals
#     - 989
#     - Patents
#     - 151
#     - Science
#     - 132
#     - Spec sheets
#     - 24
#     - Pages per Category
#     - Categories
#     - Annual Reports
#     - CCPdf (misc)
#     - Law and Regulations
#     - Manuals
#     - Patents
#     - Science
#     - Spec sheets
#
# ============================================================
# Picture 2
# ============================================================
# Caption: Figure 3: Distribution of conversion times for all documents, ordered by number of pages in a document, on all system configurations. Every dot represents one document. Log/log scale is used to even the spacing, since both number of pages and conversion times have long-tail distributions.
# Location: Page 5
#
# Embedded text elements:
#     - Figure 3: Distribution of conversion times for all documents, ordered by number of pages in a document, on all system configurations. Every dot represents one document. Log/log scale is used to even the spacing, since both number of pages and conversion times have long-tail distributions.
#     - 10 0
#     - 10 1
#     - 10 2
#     - Number of pages
#     - 10 0
#     - 10 1
#     - 10 2
#     - 10 3
#     - x86 CPU
#     - M3 Max
#     - L4 GPU
#
# ============================================================
# Picture 3
# ============================================================
# Caption: Figure 4: Contributions of PDF backend and AI models to the conversion time of a page (in seconds per page). Lower is better. Left: Ranges of time contributions for each model to pages it was applied on (i.e., OCR was applied only on pages with bitmaps, table structure was applied only on pages with tables). Right: Average time contribution to a page in the benchmark dataset (factoring in zero-time contribution for OCR and table structure models on pages without bitmaps or tables) .
# Location: Page 7
#
# Embedded text elements:
#     - Figure 4: Contributions of PDF backend and AI models to the conversion time of a page (in seconds per page). Lower is better. Left: Ranges of time contributions for each model to pages it was applied on (i.e., OCR was applied only on pages with bitmaps, table structure was applied only on pages with tables). Right: Average time contribution to a page in the benchmark dataset (factoring in zero-time contribution for OCR and table structure models on pages without bitmaps or tables) .
#     - Pdf Parse
#     - OCR
#     - Layout
#     - Table Structure
#     - Page Total
#     - 10
#     - 2
#     - 10
#     - 1
#     - 10 0
#     - 10 1
#     - sec/page
#     - Pdf Parse
#     - OCR
#     - Layout
#     - Table Structure
#     - Page Total
#     - 0.0
#     - 0.5
#     - 1.0
#     - 1.5
#     - 2.0
#     - 2.5
#     - 3.0
#     - sec/page
#     - x86 CPU
#     - M3 Max
#     - L4 GPU
#
# ============================================================
# Picture 4
# ============================================================
# Caption: Figure 5: Conversion time in seconds per page on our dataset in three scenarios, across all assets and system configurations. Lower bars are better. The configuration includes OCR and table structure recognition ( fast table option on Docling and MinerU, hi res in unstructured, as shown in table 1).
# Location: Page 7
#
# Embedded text elements:
#     - Figure 5: Conversion time in seconds per page on our dataset in three scenarios, across all assets and system configurations. Lower bars are better. The configuration includes OCR and table structure recognition ( fast table option on Docling and MinerU, hi res in unstructured, as shown in table 1).
#     - Docling
#     - Marker
#     - Mineru
#     - Unstructured
#     - 0
#     - 2
#     - 4
#     - 6
#     - 8
#     - 10
#     - 12
#     - 14
#     - 16
#     - sec/page
#     - x86 CPU
#     - M3 Max
#     - L4 GPU
#
# ============================================================
# Picture 5
# ============================================================
# Caption: Figure 6: Ecosystem of Docling integrations contributed by the Docling team or the broader community. Docling is already used for RAG, model fine-tuning, large-scale datasets creation, information extraction and agentic workflows.
# Location: Page 7
#
# Embedded text elements:
#     - Figure 6: Ecosystem of Docling integrations contributed by the Docling team or the broader community. Docling is already used for RAG, model fine-tuning, large-scale datasets creation, information extraction and agentic workflows.
#     - Docling
#     - InstructLab
#     - 🐶
#     - Bee Agent
#     - Framework
#     - 🐝
#     - LlamaIndex
#     - 🦙
#     - LangChain
#     - 🦜🔗
#     - …
#     - DataPrepKit
#     - 🧰
#     - spaCy

# %% [markdown]
# ### Visualizing Document Layout with Bounding Boxes
#
# In order to understand how each part of the document is extracted, let's visualize the extracted elements.
#
# We can do that by using one of Docling's built-in visualizers:

# %%
from docling_core.transforms.visualizer.layout_visualizer import LayoutVisualizer

layout_visualizer = LayoutVisualizer()
page_images = layout_visualizer.get_visualization(doc=img_doc)

num_pages_to_viz = 2  # first N pages to visualize
pages_to_viz = list(page_images.keys())[:num_pages_to_viz]
for page in pages_to_viz:
    display(page_images[page])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1224x1584>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1224x1584>

# %% [markdown]
# ## Advanced Features: Enrichment

# %% [markdown]
# ### Picture Classification and Description
#
# Beyond basic captioning capabilities, Docling is also able to process images using multimodal LLM's. This will give us more indepth picture descriptions to help us leverage image data more effectively.
#
# Let's try this with the integrated granite-vision model:

# %%
from docling.datamodel.pipeline_options import PictureDescriptionVlmOptions

# Configure enrichment pipeline
enrichment_options = PdfPipelineOptions(
    do_picture_description=True,
    picture_description_options=PictureDescriptionVlmOptions(  # model & prompt choice
        repo_id="ibm-granite/granite-vision-3.1-2b-preview",
        prompt="Give a detailed description of what is depicted in the image",
    ),
    generate_picture_images=True,
    images_scale=1.0,
)

converter_enriched = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=enrichment_options)
    }
)

enr_result = converter_enriched.convert(docling_paper)
enr_doc = enr_result.document
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from docling_core.types.doc.document import PictureDescriptionData
from IPython import display

html_buffer = []
# display the first 5 pictures and their captions and annotations:
for pic in enr_doc.pictures[:5]:
    html_item = (
        f"<h3>Picture <code>{pic.self_ref}</code></h3>"
        f'<img src="{pic.image.uri!s}" /><br />'
        f"<h4>Caption</h4>{pic.caption_text(doc=doc)}<br />"
    )
    for annotation in pic.annotations:
        if not isinstance(annotation, PictureDescriptionData):
            continue
        html_item += (
            f"<h4>Annotations ({annotation.provenance})</h4>{annotation.text}<br />\n"
        )
    html_buffer.append(html_item)
display.HTML("<hr />".join(html_buffer))
# Out:
# <h3>Picture <code>#/pictures/0</code></h3><img src="data:image/png;base64,..." /><br /><h4>Caption</h4>Figure 1: Sketch of Docling's pipelines and usage model. Both PDF pipeline and simple pipeline build up a DoclingDocument representation, which can be further enriched. Downstream applications can utilize Docling's API to inspect, export, or chunk the document for various purposes.<br /><h4>Annotations (ibm-granite/granite-vision-3.1-2b-preview)</h4>The image is a flowchart that illustrates the process of converting PDF files into various formats and then using them for different purposes. The flowchart is divided into three main sections: "PDF Pipeline," "Simple Pipeline," and "Enrich." Each section is represented by a different color and contains various icons and textual descriptions.
#
# ### PDF Pipeline
#
# 1. **PDF Pipeline**:
#    - **Source**: A PDF file is shown at the top left corner.
#    - **Process**:
#      - **Parse PDF pages**: A document icon is displayed, indicating the parsing of PDF pages.
#      - **OCR**: An icon representing Optical Character Recognition (OCR) is shown, indicating the OCR process.
#      - **Layout Analysis**: A document icon is displayed, indicating the layout analysis.
#      - **Table Structure**: A document icon is shown, indicating the table structure.
#      - **Assemble Document**: A document icon is displayed, indicating the assembly of the document.
#      -<br />
# <hr /><h3>Picture <code>#/pictures/1</code></h3><img src="data:image/png;base64,..." /><br /><h4>Caption</h4>Figure 2: Dataset categories and sample counts for documents and pages.<br /><h4>Annotations (ibm-granite/granite-vision-3.1-2b-preview)</h4>The image is a pie chart that illustrates the distribution of documents per category. The chart is divided into two main sections: "Documents per Category" and "Pages per Category."
#
# ### Documents per Category
#
# #### Title: Documents per Category
#
# The chart is divided into several segments, each representing a different category of documents. The categories are:
# 1. **Annual Reports**
# 2. **Patents**
# 3. **CCPdf (misc)**
# 4. **Science**
# 5. **Spec sheets**
# 6. **Law and Regulations**
#
# Each category is represented by a different color:
# - **Annual Reports**: Light blue
# - **Patents**: Red
# - **CCPdf (misc)**: Blue
# - **Science**: Green
# - **Spec sheets**: Yellow
# - **Law and Regulations**: Orange
#
# The sizes of the segments are proportional to the number of documents in each category. Here is<br />
# <hr /><h3>Picture <code>#/pictures/2</code></h3><img src="data:image/png;base64,..." /><br /><h4>Caption</h4>Figure 3: Distribution of conversion times for all documents, ordered by number of pages in a document, on all system configurations. Every dot represents one document. Log/log scale is used to even the spacing, since both number of pages and conversion times have long-tail distributions.<br /><h4>Annotations (ibm-granite/granite-vision-3.1-2b-preview)</h4>The image is a scatter plot graph that displays data points for three different categories: x86 CPU, M3 Max, and L4 GPU. The x-axis represents the "Number of pages," while the y-axis represents the "sec." The data points are color-coded to differentiate between the three categories.
#
# ### Description of the Graph:
#
# 1. **Title**: The graph does not have a title explicitly mentioned in the image. However, the x-axis is labeled "Number of pages," and the y-axis is labeled "sec."
#
# 2. **Axes**:
#    - **X-axis**: Labeled "Number of pages," ranging from 1 to 1000.
#    - **Y-axis**: Labeled "sec," ranging from 0.1 to 1000.
#
# 3. **Data Points**:
#    - **x86 CPU**: Represented by orange circles.
#    -<br />
# <hr /><h3>Picture <code>#/pictures/3</code></h3><img src="data:image/png;base64,..." /><br /><h4>Caption</h4>Figure 4: Contributions of PDF backend and AI models to the conversion time of a page (in seconds per page). Lower is better. Left: Ranges of time contributions for each model to pages it was applied on (i.e., OCR was applied only on pages with bitmaps, table structure was applied only on pages with tables). Right: Average time contribution to a page in the benchmark dataset (factoring in zero-time contribution for OCR and table structure models on pages without bitmaps or tables) .<br /><h4>Annotations (ibm-granite/granite-vision-3.1-2b-preview)</h4>The image is a bar chart with two main sections. The left section displays a scatter plot of data points, while the right section presents a bar chart with a total sum of data points.
#
# ### Left Section: Scatter Plot
# - **Axes**:
#   - **Y-Axis**: The y-axis is labeled "sec/page" and ranges from 0.01 to 20.00, with increments of 1.00.
#   - **X-Axis**: The x-axis is labeled "Page" and ranges from 0 to 30, with increments of 5.
# - **Data Points**:
#   - **Orange**: Representing the "X86 CPU" data.
#   - **Green**: Representing the "M3 Max" data.
#   - **Blue**: Representing the "L4 GPU" data.
# - **Legend**:
#   - The legend is located in the upper right corner of the<br />
# <hr /><h3>Picture <code>#/pictures/4</code></h3><img src="data:image/png;base64,..." /><br /><h4>Caption</h4>Figure 5: Conversion time in seconds per page on our dataset in three scenarios, across all assets and system configurations. Lower bars are better. The configuration includes OCR and table structure recognition ( fast table option on Docling and MinerU, hi res in unstructured, as shown in table 1).<br /><h4>Annotations (ibm-granite/granite-vision-3.1-2b-preview)</h4>The image is a bar chart that compares the performance of four different algorithms or methods in terms of "sec/page" across four different categories: "Docling," "Marker," "Mineru," and "Unstructured." The chart is divided into four vertical columns, each representing one of the categories. The horizontal axis is labeled "sec/page," which indicates the performance metric measured in seconds per page.
#
# ### Description of the Chart:
#
# 1. **Title**: The chart does not have a title, but it is a bar chart comparing the performance of four different algorithms or methods.
#
# 2. **Axes**:
#    - **X-Axis (Horizontal)**: Labeled "sec/page," this axis measures the performance metric in seconds per page.
#    - **Y-Axis (Vertical)**: Labeled "sec/page," this axis measures the performance metric in seconds per page.
#
# 3. **Legend**:
#    - The legend is located on the<br />

# %% [markdown]
# ## Visual Language Models (VLMs)
#
# A recent feature of Docling is the use of a single shot VLM to process documents. This means that instead the traditional conversion pipeline, we send the docment to a custom tuned VLM that can extract all the content directly.

# %% [markdown]
# ### Using SmolDocling
#
# [SmolDocling](https://huggingface.co/ds4sd/SmolDocling-256M-preview) is a compact (256M parameters) vision-language model for document conversion:

# %%
import platform
from docling.datamodel.pipeline_options import (  # Additional imports for VLM
    VlmPipelineOptions,
    smoldocling_vlm_conversion_options,
    smoldocling_vlm_mlx_conversion_options,
)
from docling.pipeline.vlm_pipeline import VlmPipeline

if (
    "darwin" in platform.system().lower()
    and "arm64" in platform.machine().lower()
):  # optimized for Apple Silicon (MLX)
    vlm_options = smoldocling_vlm_mlx_conversion_options
else:
    vlm_options = smoldocling_vlm_conversion_options

vlm_pipeline_options = VlmPipelineOptions(
    force_backend_text=False,
    vlm_options=vlm_options,
)

converter_vlm = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=vlm_pipeline_options,
            pipeline_cls=VlmPipeline,
        )
    }
)

vlm_result = converter_vlm.convert(docling_paper)
vlm_doc = vlm_result.document
# Out:
# /Users/pva/work/github.com/DS4SD/docling/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2718: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
vlm_md_out = vlm_doc.export_to_markdown()

# printing an excerpt
print(f"{vlm_md_out[:2000]}...")
# Out:
# ## Docling: An Efficient Open-Source Toolkit for AI-driven Document Conversion
#
# Nikolaos Livathinos ∗ , Christoph Auer ∗ , Maksym Lysak, Ahmed Nassar, Michele Dolfi, Panagiotis Vagenas, Cesar Berrospi, Mateo Omenetti, Kasper Dinkla, Yusik Kim, Shubham Gupta, Rafael Teixeira de Lima, Valery Weber, Lucas Morin, Ingmar Meijer, Viktor Kuropatinykh, Peter W. J. Staar
#
# IBM Research, Rüschlikon, Switzerland Please send correspondence to: deepsearch-core@zurich.ibm.com
#
# ## Abstract
#
# We introduce Docling , an easy-to-use, self-contained, MITlicensed, open-source toolkit for document conversion, that can parse several types of popular document formats into a unified, richly structured representation. It is powered by state-of-the-art specialized AI models for layout analysis (DocLayNet) and table structure recognition (TableFormer), and runs efficiently on commodity hardware in a small resource budget. Docling is released as a Python package and can be used as a Python API or as a CLI tool. Docling's modular architecture and efficient document representation make it easy to implement extensions, new features, models, and customizations. Docling has been already integrated in other popular open-source frameworks (e.g., LangChain, Llamalendex, SpaCy), making it a natural fit for the processing of documents and the development of high-end applications. The open-source community has fully engaged in using, promoting, and developing for Docling, which gathered 10k stars on GitHub in less than a month and was reported as the No. 1 trending repository in GitHub worldwide in November 2024.
#
# Repository - https://github.com/DS4SD/docling
#
# ## 1 Introduction
#
# Converting documents back into a unified machineprocessable format has been a major challenge for decades due to their huge variability in formats, weak standardization and printing-optimized characteristic, which often discards structural features and metadata. With the advent of LLMs and popular application patterns such as retrie...

# %% [markdown]
# ## Summary and Next Steps
#
# ### What You've Accomplished in Lab 1
#
# Congratulations! You've mastered the critical first step in document AI:
#
# - Basic and advanced document conversion with visual feedback
# - Multiple export formats with visualization options
# - Table and image extraction with visual verification
# - Enrichment models and VLMs
#
# ### Your Journey Continues
#
# You're now ready for:
# - **Lab 2**: Learn intelligent chunking strategies to optimize for retrieval
# - **Lab 3**: Build a complete multimodal RAG system with visual grounding
#
# ### Next Steps
#
# 1. **Practice with Your Documents**
#    - Try different document types
#    - Experiment with configuration options
#    - Validate extraction quality
#
# 2. **Proceed Lab 2**
#    - Gather a collection of documents
#    - Think about how you'd want to chunk them
#    - Consider what makes a good chunk for retrieval
#
# Docling provides a powerful, flexible framework for document processing that can be adapted to many use cases. The modular architecture allows you to enable only the features you need, while the visualization capabilities ensure transparency and accuracy in your document processing pipeline.
#
# For more information:
# - GitHub: https://github.com/docling-project/docling
# - Documentation: https://docling-project.github.io/docling/
# - Technical Report: https://arxiv.org/abs/2408.09869
# - Examples: https://github.com/docling-project/docling/tree/main/examples
